# %%
import pandas as pd # importing the pandas library and giving it an alias of pd to make it easier to use in our code and we will use this library to read in the movies.csv and ratings.csv files and to manipulate the data in these files to analyze the genres of the movies in the dataframe and we will also display the first few rows of the dataframes to see the changes made to the dataframes after reading in the data from the csv files and we will also check the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after reading in the data from the csv files and checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis
import numpy as np # importing the numpy library and giving it an alias of np to make it easier to use in our code and we will use this library to perform mathematical operations on the data in the dataframes to analyze the genres of the movies in the dataframe and we will also display the first few rows of the dataframes to see the changes made to the dataframes after performing mathematical operations on the data in the dataframes to analyze the genres of the movies in the dataframe and we will also check the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after performing mathematical operations on the data in the dataframes and checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis
import seaborn as sns # importing the seaborn library and giving it an alias of sns to make it easier to use in our code and we will use this library to create visualizations of the data in the dataframes to analyze the genres of the movies in the dataframe and we will also display the first few rows of the dataframes to see the changes made to the dataframes after creating visualizations of the data in the dataframes to analyze the genres of the movies in the dataframe and we will also check the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after creating visualizations of the data in the dataframes and checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis
import matplotlib.pyplot as plt # importing the matplotlib.pyplot library and giving it an alias of plt to make it easier to use in our code and we will use this library to create visualizations of the data in the dataframes to analyze the genres of the movies in the dataframe and we will also display the first few rows of the dataframes to see the changes made to the dataframes after creating visualizations of the data in the dataframes to analyze the genres of the movies in the dataframe and we will also check the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after creating visualizations of the data in the dataframes and checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis

from sklearn.model_selection import train_test_split # importing the train_test_split function from the sklearn.model_selection module to split the data into training and testing sets to analyze the genres of the movies in the dataframe and we will also display the first few rows of the dataframes to see the changes made to the dataframes after splitting the data into training and testing sets to analyze the genres of the movies in the dataframe and we will also check the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after splitting the data into training and testing sets and checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNetCV # importing the LinearRegression, Ridge, Lasso, and ElasticNetCV classes from the sklearn.linear_model module to create linear regression models to analyze the genres of the movies in the dataframe and we will also display the first few rows of the dataframes to see the changes made to the dataframes after creating linear regression models to analyze the genres of the movies in the dataframe and we will also check the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after creating linear regression models and checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error # importing the LinearRegression, Ridge, Lasso, and ElasticNetCV classes from the sklearn.linear_model module to create linear regression models to analyze the genres of the movies in the dataframe and we will also display the first few rows of the dataframes to see the changes made to the dataframes after creating linear regression models to analyze the genres of the movies in the dataframe and we will also check the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after creating linear regression models and checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis
from scipy.stats import normaltest, skew, boxcox # importing the normaltest, skew, and boxcox functions from the scipy.stats module to perform statistical tests on the data in the dataframes to analyze the genres of the movies in the dataframe and we will also display the first few rows of the dataframes to see the changes made to the dataframes after performing statistical tests on the data in the dataframes to analyze the genres of the movies in the dataframe and we will also check the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframes to see the changes made to the dataframes after performing statistical tests on the data in the dataframes and checking the data types of the columns in the dataframes to see if they are of the correct data type for analysis

# %%
df = pd.read_csv('data/FuelConsumption.csv')

df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
df.shape # displaying the shape of the df dataframe to see the number of rows and columns in the dataframe and we will also display the first few rows of the dataframe to see the changes made to the dataframe after reading in the data from the csv file and we will also check the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after reading in the data from the csv file and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
# Out:
# (1067, 13)

# %%
df.columns # displaying the columns of the df dataframe to see the names of the columns in the dataframe and we will also display the first few rows of the dataframe to see the changes made to the dataframe after reading in the data from the csv file and we will also check the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after reading in the data from the csv file and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
df.drop(
    columns=['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'TRANSMISSION', 'FUELTYPE'], # dropping the columns that are not relevant to our analysis of the genres of the movies in the dataframe by using the drop method and specifying the columns to drop using the columns parameter and passing a list of the column names we want to drop and specifying the axis to drop the columns from using the axis parameter and setting it to 1 to drop the columns from the dataframe and setting inplace to True to make the changes to the dataframe permanent and we will also display the first few rows of the dataframe to see the changes made to the dataframe after dropping the irrelevant columns from the dataframe and we will also check the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after dropping the irrelevant columns from the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
    axis=1, # dropping the columns that are not relevant to our analysis of the genres of the movies in the dataframe by using the drop method and specifying the columns to drop using the columns parameter and passing a list of the column names we want to drop and specifying the axis to drop the columns from using the axis parameter and setting it to 1 to drop the columns from the dataframe and setting
    inplace=True # dropping the columns that are not relevant to our analysis of the genres of the movies in the dataframe by using the drop method and specifying the columns to drop using the columns parameter and passing a list of the column names we want to drop and specifying the axis to drop the columns from using the axis parameter and setting it to 1 to drop the columns from the dataframe and setting inplace to True to make the changes to the dataframe permanent and we will also display the first few rows of the dataframe to see the changes made to the dataframe after dropping the irrelevant columns from the dataframe and we will also check the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after dropping the irrelevant columns from the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
) # dropping the columns that are not relevant to our analysis of the genres of the movies in the dataframe by using the drop method and specifying the columns to drop using the columns parameter and passing a list of the column names we want to drop and specifying the axis to drop the columns from using the axis parameter and setting it to 1 to drop the columns from the dataframe and setting inplace to True to make the changes to the dataframe permanent and we will also display the first few rows of the dataframe to see the changes made to the dataframe after dropping the irrelevant columns from the dataframe and we will also check the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after dropping the irrelevant columns from the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

df.head()
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0         2.0          4                   9.9                  6.7
# 1         2.4          4                  11.2                  7.7
# 2         1.5          4                   6.0                  5.8
# 3         3.5          6                  12.7                  9.1
# 4         3.5          6                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
df.describe() # displaying the summary statistics of the df dataframe to see the mean, standard deviation, minimum, and maximum values of the columns in the dataframe and we will also display the first few rows of the dataframe to see the changes made to the dataframe after displaying the summary statistics of the dataframe and we will also check the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after displaying the summary statistics of the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
# Out:
#         ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# count  1067.000000  1067.000000           1067.000000          1067.000000
# mean      3.346298     5.794752             13.296532             9.474602
# std       1.415895     1.797447              4.101253             2.794510
# min       1.000000     3.000000              4.600000             4.900000
# 25%       2.000000     4.000000             10.250000             7.500000
# 50%       3.400000     6.000000             12.600000             8.800000
# 75%       4.300000     8.000000             15.550000            10.850000
# max       8.400000    12.000000             30.200000            20.500000
#
#        FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# count           1067.000000               1067.000000   1067.000000
# mean              11.580881                 26.441425    256.228679
# std                3.485595                  7.468702     63.372304
# ...

# %%
df.corr()['CO2EMISSIONS'].sort_values(ascending=False) # calculating the correlation between the CO2EMISSIONS column and the other columns in the dataframe using the corr method and specifying the column to calculate the correlation with using the ['CO2EMISSIONS'] syntax and sorting the values in descending order using the sort_values method and setting ascending to False to sort the values in descending order and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calculating the correlation between the CO2EMISSIONS column and the other columns in the dataframe and we will also check the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calculating the correlation between the CO2EMISSIONS column and the other columns in the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
# Out:
# CO2EMISSIONS                1.000000
# FUELCONSUMPTION_CITY        0.898039
# FUELCONSUMPTION_COMB        0.892129
# ENGINESIZE                  0.874154
# FUELCONSUMPTION_HWY         0.861748
# CYLINDERS                   0.849685
# FUELCONSUMPTION_COMB_MPG   -0.906394
# Name: CO2EMISSIONS, dtype: float64

# %%
def normality_report(data_set: pd.DataFrame) -> pd.DataFrame:
    results = []

    for col in data_set.select_dtypes(include='number').columns:

        stat, p = normaltest(data_set[col].dropna()) # performing the normality test on the column using the normaltest function from the scipy.stats module and specifying the column to perform the test on using the [col] syntax and dropping any missing values from the column using the dropna method to ensure that the normality test is performed on a clean dataset and we will also display the first few rows of the dataframe to see the changes made to the dataframe after performing the normality test on the column and we will also check the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after performing the normality test on the column and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
        normal = p > 0.05 # determining if the column is normally distributed based on the p-value from the normality test and setting a threshold of 0.05 to determine if the column is normally distributed or not and we will also display the first few rows of the dataframe to see the changes made to the dataframe after determining if the column is normally distributed based on the p-value from the normality test and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after determining if the column is normally distributed based on the p-value from the normality test and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

        results.append({
            "Column": col, # appending the column name to the results list as a dictionary with the column name, K2 statistic, p-value, whether the column is normally distributed or not, and an interpretation of the results based on whether the column is normally distributed or not and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the normality test for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the normality test for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
            "K2 Statistic": round(stat, 3), # appending the K2 statistic from the normality test to the results list as a dictionary with the column name, K2 statistic, p-value, whether the column is normally distributed or not, and an interpretation of the results based on whether the column is normally distributed or not and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the normality test for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the normality test for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
            "p-value": round(p, 4), # appending the p-value from the normality test to the results list as a dictionary with the column name, K2 statistic, p-value, whether the column is normally distributed or not, and an interpretation of the results based on whether the column is normally distributed or not and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the normality test for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the normality test for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
            "Is Normal": "Yes" if normal else "No", # appending whether the column is normally distributed or not to the results list as a dictionary with the column name, K2 statistic, p-value, whether the column is normally distributed or not, and an interpretation of the results based on whether the column is normally distributed or not and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the normality test for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the normality test for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
            "Interpretation": (
                "Fits Normal Distribution"
                if normal
                else "Does NOT Fit Normal Distribution"
            ) # determining the interpretation of the results based on whether the column is normally distributed or not and setting the interpretation to "Fits Normal Distribution" if the column is normally distributed and "Does NOT Fit Normal Distribution" if the column is not normally distributed and we will also display the first few rows of the dataframe to see the changes made to the dataframe after determining the interpretation of the results based on whether the column is normally distributed or not and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after determining the interpretation of the results based on whether the column is normally distributed or not and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
        }) # appending the results of the normality test for each column to the results list as a dictionary with the column name, K2 statistic, p-value, whether the column is normally distributed or not, and an interpretation of the results based on whether the column is normally distributed or not and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the normality test for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the normality test for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

    return pd.DataFrame(results) # returning the results list as a dataframe to display the results of the normality test for each column in a tabular format and we will also display the first few rows of the dataframe to see the changes made to the dataframe after returning the results list as a dataframe to display the results of the normality test for each column in a tabular format and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after returning the results list as a dataframe to display the results of the normality test for each column in a tabular format and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

# %%
normal_test_result = normality_report(data_set=df) # calling the normality_report function and passing the df dataframe as the data_set parameter to perform the normality test on the columns in the dataframe and store the results in a variable called normal_test_result and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calling the normality_report function and passing the df dataframe as the data_set parameter to perform the normality test on the columns in the dataframe and store the results in a variable called normal_test_result and we will also check the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calling the normality_report function and passing the df dataframe as the data_set parameter to perform the normality test on the columns in the dataframe and store the results in a variable called normal_test_result and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

normal_test_result
# Out:
#                      Column  K2 Statistic  p-value Is Normal  \
# 0                ENGINESIZE        75.054      0.0        No
# 1                 CYLINDERS        97.043      0.0        No
# 2      FUELCONSUMPTION_CITY       129.822      0.0        No
# 3       FUELCONSUMPTION_HWY       229.154      0.0        No
# 4      FUELCONSUMPTION_COMB       163.716      0.0        No
# 5  FUELCONSUMPTION_COMB_MPG        67.915      0.0        No
# 6              CO2EMISSIONS        43.711      0.0        No
#
#                      Interpretation
# 0  Does NOT Fit Normal Distribution
# 1  Does NOT Fit Normal Distribution
# 2  Does NOT Fit Normal Distribution
# 3  Does NOT Fit Normal Distribution
# 4  Does NOT Fit Normal Distribution
# 5  Does NOT Fit Normal Distribution
# 6  Does NOT Fit Normal Distribution

# %%
def skewness_report(data_set: pd.DataFrame) -> pd.DataFrame:
    results = []

    for col in data_set.select_dtypes(include='number').columns:

        data = data_set[col].dropna() # dropping any missing values from the column using the dropna method to ensure that the skewness analysis is performed on a clean dataset and we will also display the first few rows of the dataframe to see the changes made to the dataframe after dropping any missing values from the column to ensure that the skewness analysis is performed on a clean dataset and we will also check the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after dropping any missing values from the column and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
        skew_val = skew(data) # calculating the skewness of the column using the skew function from the scipy.stats module and specifying the column to calculate the skewness for using the [col] syntax and dropping any missing values from the column using the dropna method to ensure that the skewness analysis is performed on a clean dataset and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calculating the skewness of the column and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calculating the skewness of the column and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

        if skew_val > 0.5:
            direction = 'Right-Skewed'
        elif skew_val < -0.5:
            direction = 'Left-Skewed'
        else:
            direction = 'Simetric'
        
        abs_val = abs(skew_val) # calculating the absolute value of the skewness to determine the severity of the skewness and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calculating the absolute value of the skewness to determine the severity of the skewness and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calculating the absolute value of the skewness to determine the severity of the skewness and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
        if abs_val < 0.5:
            severity = '~Simetric'
        elif abs_val < 1:
            severity = 'Low skewed'
        elif abs_val < 2:
            severity = 'Medium skewed'
        else:
            severity = 'Heavy skewed'
        
        results.append({
            'Column': col, # appending the column name to the results list as a dictionary with the column name, skewness value, direction of skewness, and severity of skewness and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the skewness analysis for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the skewness analysis for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
            'Skewness': round(skew_val, 3), # appending the skewness value to the results list as a dictionary with the column name, skewness value, direction of skewness, and severity of skewness and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the skewness analysis for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the skewness analysis for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
            'Direction': direction, # appending the results of the skewness analysis for each column to the results list as a dictionary with the column name, skewness value, direction of skewness, and severity of skewness and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the skewness analysis for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the skewness analysis for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
            'Severity': severity # appending the results of the skewness analysis for each column to the results list as a dictionary with the column name, skewness value, direction of skewness, and severity of skewness and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the skewness analysis for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the skewness analysis for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
        }) # appending the results of the skewness analysis for each column to the results list as a dictionary with the column name, skewness value, direction of skewness, and severity of skewness and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the skewness analysis for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after appending the results of the skewness analysis for each column to the results list and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

    return (
        pd.DataFrame(results)
            .sort_values(
                by='Skewness',
                ascending=False
            )
            .reset_index(drop=True) # returning the results list as a dataframe to display the results of the skewness analysis for each column in a tabular format and sorting the values by the skewness value in descending order using the sort_values method and setting ascending to False to sort the values in descending order and resetting the index of the dataframe using the reset_index method and setting drop to True to drop the old index and create a new index for the sorted dataframe and we will also display the first few rows of the dataframe to see the changes made to the dataframe after returning the results list as a dataframe to display the results of the skewness analysis for each column in a tabular format and sorting the values by the skewness value in descending order and resetting the index of the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after returning the results list as a dataframe to display the results of the skewness analysis for each column in a tabular format and sorting the values by the skewness value in descending order and resetting the index of the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
    ) # returning the results list as a dataframe to display the results of the skewness analysis for each column in a tabular format and we will also display the first few rows of the dataframe to see the changes made to the dataframe after returning the results list as a dataframe to display the results of the skewness analysis for each column in a tabular format and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

# %%
skewness_result = skewness_report(data_set=df) # calling the skewness_report function and passing the df dataframe as the data_set parameter to perform the skewness analysis on the columns in the dataframe and store the results in a variable called skewness_result and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calling the skewness_report function and passing the df dataframe as the data_set parameter to perform the skewness analysis on the columns in the dataframe and store the results in a variable called skewness_result and we will also check the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calling the skewness_report function and passing the df dataframe as the data_set parameter to perform the skewness analysis on the columns in the dataframe and store the results in a variable called skewness_result and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

skewness_result
# Out:
#                      Column  Skewness     Direction       Severity
# 0       FUELCONSUMPTION_HWY     1.262  Right-Skewed  Medium skewed
# 1      FUELCONSUMPTION_COMB     1.031  Right-Skewed  Medium skewed
# 2      FUELCONSUMPTION_CITY     0.899  Right-Skewed     Low skewed
# 3                 CYLINDERS     0.795  Right-Skewed     Low skewed
# 4  FUELCONSUMPTION_COMB_MPG     0.585  Right-Skewed     Low skewed
# 5                ENGINESIZE     0.567  Right-Skewed     Low skewed
# 6              CO2EMISSIONS     0.519  Right-Skewed     Low skewed

# %%
df_box = df.copy() # creating a copy of the df dataframe and storing it in a new variable called df_box to perform the Box-Cox transformation on the columns in the dataframe without modifying the original dataframe and we will also display the first few rows of the dataframe to see the changes made to the dataframe after creating a copy of the df dataframe and storing it in a new variable called df_box to perform the Box-Cox transformation on the columns in the dataframe without modifying the original dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after creating a copy of the df dataframe and storing it in a new variable called df_box to perform the Box-Cox transformation on the columns in the dataframe without modifying the original dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

for col in df.select_dtypes(include="number").columns:
    
    # Sadece pozitif değerli kolonlar
    if (df[col] <= 0).any():
        shifted = df[col] - df[col].min() + 1 # shifting the values in the column to make them positive by subtracting the minimum value from the column and adding 1 to ensure that all values are positive and we will also display the first few rows of the dataframe to see the changes made to the dataframe after shifting the values in the column to make them positive and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after shifting the values in the column to make them positive and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
        df_box[col], _ = boxcox(shifted) # performing the Box-Cox transformation on the columns in the dataframe using the boxcox function from the scipy.stats module and specifying the column to perform the transformation on using the [col] syntax and storing the transformed values back in the same column in the df_box dataframe and we will also display the first few rows of the dataframe to see the changes made to the dataframe after performing the Box-Cox transformation on the columns in the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after performing the Box-Cox transformation on the columns in the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
    else:
        df_box[col], _ = boxcox(df[col]) # performing the Box-Cox transformation on the columns in the dataframe using the boxcox function from the scipy.stats module and specifying the column to perform the transformation on using the [col] syntax and storing the transformed values back in the same column in the df_box dataframe and we will also display the first few rows of the dataframe to see the changes made to the dataframe after performing the Box-Cox transformation on the columns in the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after performing the Box-Cox transformation on the columns in the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

df_box.head()
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0    0.720432   0.998389              2.202310             1.055183
# 1    0.919293   0.998389              2.315860             1.090531
# 2    0.414702   0.998389              1.736325             1.014736
# 3    1.343783   1.181131              2.431028             1.128701
# 4    1.343783   1.181131              2.386742             1.118862
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0              1.585580                  6.193556      7.537387
# 1              1.649048                  5.830644      7.774938
# 2              1.380861                  7.329359      6.836256
# 3              1.721834                  5.430828      8.062912
# 4              1.699064                  5.635917      7.973613

# %%
skewness_report_v1 = skewness_report(data_set=df_box) # calling the skewness_report function and passing the df_box dataframe as the data_set parameter to perform the skewness analysis on the columns in the df_box dataframe after performing the Box-Cox transformation on the columns in the dataframe and store the results in a variable called skewness_report_v1 and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calling the skewness_report function and passing the df_box dataframe as the data_set parameter to perform the skewness analysis on the columns in the df_box dataframe after performing the Box-Cox transformation on the columns in the dataframe and store the results in a variable called skewness_report_v1 and we will also check the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calling the skewness_report function and passing the df_box dataframe as the data_set parameter to perform the skewness analysis on the columns in the df_box dataframe after performing the Box-Cox transformation on the columns in the dataframe and store the results in a variable called skewness_report_v1 and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

skewness_report_v1
# Out:
#                      Column  Skewness Direction   Severity
# 0                 CYLINDERS     0.063  Simetric  ~Simetric
# 1       FUELCONSUMPTION_HWY     0.026  Simetric  ~Simetric
# 2      FUELCONSUMPTION_COMB     0.005  Simetric  ~Simetric
# 3      FUELCONSUMPTION_CITY    -0.000  Simetric  ~Simetric
# 4              CO2EMISSIONS    -0.003  Simetric  ~Simetric
# 5  FUELCONSUMPTION_COMB_MPG    -0.004  Simetric  ~Simetric
# 6                ENGINESIZE    -0.016  Simetric  ~Simetric

# %%
before = skewness_report(df)[["Column", "Skewness"]] # calling the skewness_report function and passing the original df dataframe as the data_set parameter to perform the skewness analysis on the columns in the original dataframe and storing the results in a variable called before and selecting only the "Column" and "Skewness" columns from the results to compare with the results after performing the Box-Cox transformation on the columns in the dataframe and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calling the skewness_report function and passing the original df dataframe as the data_set parameter to perform the skewness analysis on the columns in the original dataframe and storing the results in a variable called before and selecting only the "Column" and "Skewness" columns from the results to compare with the results after performing the Box-Cox transformation on the columns in the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calling the skewness_report function and passing the original df dataframe as the data_set parameter to perform the skewness analysis on the columns in the original dataframe and storing the results in a variable called before and selecting only the "Column" and "Skewness" columns from the results to compare with the results after performing the Box-Cox transformation on the columns in the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
after = skewness_report(df_box)[["Column", "Skewness"]] # calling the skewness_report function and passing the df_box dataframe as the data_set parameter to perform the skewness analysis on the columns in the df_box dataframe after performing the Box-Cox transformation on the columns in the dataframe and storing the results in a variable called after and selecting only the "Column" and "Skewness" columns from the results to compare with the results before performing the Box-Cox transformation on the columns in the dataframe and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calling the skewness_report function and passing the df_box dataframe as the data_set parameter to perform the skewness analysis on the columns in the df_box dataframe after performing the Box-Cox transformation on the columns in the dataframe and storing the results in a variable called after and selecting only the "Column" and "Skewness" columns from the results to compare with the results before performing the Box-Cox transformation on the columns in the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calling the skewness_report function and passing the df_box dataframe as the data_set parameter to perform the skewness analysis on the columns in the df_box dataframe after performing the Box-Cox transformation on the columns in the dataframe and storing the results in a variable called after and selecting only the "Column" and "Skewness" columns from the results to compare with the results before performing the Box-Cox transformation on the columns in the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

comparison = before.merge(after, on="Column", suffixes=("_Before", "_After")) # merging the before and after dataframes on the "Column" column to compare the skewness values before and after performing the Box-Cox transformation on the columns in the dataframe and storing the merged results in a new dataframe called comparison and we will also display the first few rows of the dataframe to see the changes made to the dataframe after merging the before and after dataframes on the "Column" column to compare the skewness values before and after performing the Box-Cox transformation on the columns in the dataframe and storing the merged results in a new dataframe called comparison and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after merging the before and after dataframes on the "Column" column to compare the skewness values before and after performing the Box-Cox transformation on the columns in the dataframe and storing the merged results in a new dataframe called comparison and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

comparison["Improvement"] = (
    abs(comparison["Skewness_Before"]) -
    abs(comparison["Skewness_After"])
) # calculating the improvement in skewness by taking the absolute value of the skewness before performing the Box-Cox transformation and subtracting the absolute value of the skewness after performing the Box-Cox transformation and storing the improvement values in a new column called "Improvement" in the comparison dataframe and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calculating the improvement in skewness and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after calculating the improvement in skewness and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis

comparison.sort_values(by="Improvement", ascending=False)
# Out:
#                      Column  Skewness_Before  Skewness_After  Improvement
# 0       FUELCONSUMPTION_HWY            1.262           0.026        1.236
# 1      FUELCONSUMPTION_COMB            1.031           0.005        1.026
# 2      FUELCONSUMPTION_CITY            0.899          -0.000        0.899
# 3                 CYLINDERS            0.795           0.063        0.732
# 4  FUELCONSUMPTION_COMB_MPG            0.585          -0.004        0.581
# 5                ENGINESIZE            0.567          -0.016        0.551
# 6              CO2EMISSIONS            0.519          -0.003        0.516

# %%
dpi = 100
plt.figure(dpi=dpi)

sns.heatmap(
    np.round(df_box.corr(), 3),
    annot=True,
    cmap='Reds'
) # creating a heatmap to visualize the correlation between the columns in the df_box dataframe after performing the Box-Cox transformation on the columns in the dataframe and using the corr method to calculate the correlation matrix and rounding the values to 1 decimal place using the round method and annotating the heatmap with the correlation values using annot=True and setting the color map to 'Reds' to visualize the strength of the correlations with different shades of red and we will also display the first few rows of the dataframe to see the changes made to the dataframe after creating a heatmap to visualize the correlation between the columns in the df_box dataframe after performing the Box-Cox transformation on the columns in the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after creating a heatmap to visualize the correlation between the columns in the df_box dataframe after performing the Box-Cox transformation on the columns in the dataframe and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
# Out:
# <Axes: >

# %%
try:
    fig, axes = plt.subplots(2, 2, figsize=(14, 12))

    colors = ["#FF6F61", "#6A4C93", "#00A8A8", "#F4A261", "#2A9D8F"]

    # İlk görselde FUELCONSUMPTION_COMB ve CO2EMISSIONS arasındaki ilişkiyi dağılım grafiğinde gösterelim
    axes[0, 0].scatter(df_box['FUELCONSUMPTION_COMB'], df_box['CO2EMISSIONS'], color=colors[0], alpha=0.7) # creating a scatter plot to visualize the relationship between FUELCONSUMPTION_COMB and CO2EMISSIONS using the scatter method from the axes object and specifying the x and y values as the FUELCONSUMPTION_COMB and CO2EMISSIONS columns from the df_box dataframe respectively and setting the color of the points to the first color in the colors list and setting the alpha value to 0.7 to make the points slightly transparent and we will also display the first few rows of the dataframe to see the changes made to the dataframe after creating a scatter plot to visualize the relationship between FUELCONSUMPTION_COMB and CO2EMISSIONS and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis 
    axes[0, 0].set_title('FUELCONSUMPTION_COMB vs CO2EMISSIONS', fontsize=14, color='black') # setting the title of the first subplot to 'FUELCONSUMPTION_COMB vs CO2EMISSIONS' and specifying the font size as 14 and the color as red to make the title stand out and we will also display the first few rows of the dataframe to see the changes made to the dataframe after setting the title of the first subplot and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after setting the title of the first subplot and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
    axes[0, 0].set_xlabel('FUELCONSUMPTION_COMB', fontsize=10, color='black') # setting the x-axis label of the first subplot to 'FUELCONSUMPTION_COMB' and specifying the font size as 10 and the color as red to make the label stand out and we will also display the first few rows of the dataframe to see the changes made to the dataframe after setting the x-axis label of the first subplot and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after setting the x-axis label of the first subplot and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis 
    axes[0, 0].set_ylabel('CO2EMISSIONS', fontsize=10, color='black') # setting the y-axis label of the first subplot to 'CO2EMISSIONS' and specifying the font size as 10 and the color as red to make the label stand out and we will also display the first few rows of the dataframe to see the changes made to the dataframe after setting the y-axis label of the first subplot and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis and we will also display the first few rows of the dataframe to see the changes made to the dataframe after setting the y-axis label of the first subplot and checking the data types of the columns in the dataframe to see if they are of the correct data type for analysis
 
    axes[0, 1].scatter(df_box['FUELCONSUMPTION_COMB_MPG'], df_box['CO2EMISSIONS'], color=colors[1],  alpha=0.7)
    axes[0, 1].set_xlabel('FUELCONSUMPTION_COMB_MPG', fontsize=10, color='black')
    axes[0, 1].set_ylabel('CO2EMISSIONS', fontsize=10, color='black')
    axes[0, 1].set_title('FUELCONSUMPTION_COMB_MPG vs CO2EMISSIONS', fontsize=14, color='black')

    axes[1, 0].scatter(df_box['CYLINDERS'], df_box['CO2EMISSIONS'], color=colors[2],  alpha=0.7)
    axes[1, 0].set_title('CYLINDERS vs CO2EMISSIONS', fontsize=14, color='black')
    axes[1, 0].set_xlabel('CYLINDERS', fontsize=10, color='black')
    axes[1, 0].set_ylabel('CO2EMISSIONS', fontsize=10, color='black')

    axes[1, 1].scatter(df_box['FUELCONSUMPTION_CITY'], df_box['CO2EMISSIONS'], color=colors[3],  alpha=0.7)
    axes[1, 1].set_title('FUELCONSUMPTION_CITY vs CO2EMISSIONS', fontsize=14, color='black')
    axes[1, 1].set_xlabel('FUELCONSUMPTION_CITY', fontsize=10, color='black')
    axes[1, 1].set_ylabel('CO2EMISSIONS', fontsize=10, color='black')

    plt.tight_layout()
    plt.show()

except Exception as e:
    print("Hata oluştu:", e)

# %%
# Selected columns dataframe
df_selected = df_box[['FUELCONSUMPTION_COMB', 'CO2EMISSIONS']]

df_selected.head()
# Out:
#    FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0              1.585580      7.537387
# 1              1.649048      7.774938
# 2              1.380861      6.836256
# 3              1.721834      8.062912
# 4              1.699064      7.973613

# %%
df_train, df_test = train_test_split(df_selected, train_size=0.8, random_state=42)

print(
    f'Train Set: {df_train.shape}\n'
    f'Test Set: {df_test.shape}'
)
# Out:
# Train Set: (853, 2)
# Test Set: (214, 2)

# %%
regression = LinearRegression(
    fit_intercept=True,
    copy_X=True,
    n_jobs=-1
)

train_x = np.asarray(df_train[['FUELCONSUMPTION_COMB']])
train_y = np.asarray(df_train[['CO2EMISSIONS']])

regression.fit(train_x, train_y)

coefficient = regression.coef_[0][0]
intercept = regression.intercept_[0]

print(
    f'Coefficient: {coefficient}\n'
    f'Intercept: {intercept}'
)
# Out:
# Coefficient: 3.3538414747419303
# Intercept: 2.2642402704481253

# %%
plt.scatter(df_train['FUELCONSUMPTION_COMB'], df_train['CO2EMISSIONS'], color='blue')
plt.plot(train_x, coefficient * train_x + intercept, c='green', lw=3)
plt.title(label='Relation about between Fuel Consuption and Co2', color='red', fontsize=14)
plt.xlabel(xlabel='Fuel Consuption', color='red', fontsize=14)
plt.ylabel(ylabel='Co2', color='red', fontsize=14)
plt.grid()
plt.show()

# %%
test_x = np.asarray(df_test[['FUELCONSUMPTION_COMB']])
test_y = np.asarray(df_test[['CO2EMISSIONS']])

# y = intecpt + coefficient * x
test_prediction = regression.predict(test_x)

result_df = pd.DataFrame({
    'Real Values': test_y.flatten(),
    'Estimated Values': test_prediction.flatten()
})

result_df.head()
# Out:
#    Real Values  Estimated Values
# 0     8.423902          8.316950
# 1     7.774938          7.794884
# 2     8.354579          8.268623
# 3     7.774938          7.794884
# 4     7.644986          7.682955

# %%
r2_score = r2_score(y_true=test_y, y_pred=test_prediction)
print(f'R2 Score: {r2_score:.2f}')
# Out:
# R2 Score: 0.89

# %%
mae = mean_absolute_error(y_true=test_y, y_pred=test_prediction)
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Absolute Error: 0.11

# %%
mse = mean_squared_error(y_true=test_y, y_pred=test_prediction)
print(f'Mean Squared Error: {mse:.2f}')
# Out:
# Mean Squared Error: 0.03
